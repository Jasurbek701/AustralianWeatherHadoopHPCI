# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Out:
# --2024-04-08 03:15:07--  https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.208.237, 135.181.214.104, 2a01:4f8:10a:39da::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.208.237|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M  25.1MB/s    in 29s
#
# 2024-04-08 03:15:36 (24.3 MB/s) - ‘hadoop-3.3.6.tar.gz’ saved [730107476/730107476]

# %%
# !tar -xzf hadoop-3.3.6.tar.gz

# %%
# !cp -r hadoop-3.3.6 /usr/local

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %%
import os
# BEGIN YOUR CODE HERE

#os.environ["JAVA_HOME"] = ":/usr/lib/jvm/java-11-openj"
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"

# END YOUR CODE HERE

# %%
# !echo $JAVA_HOME
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64

# %%
import os
os.environ['PATH'] += ':/usr/local/hadoop-3.3.6/bin'

# %%
# !echo $PATH
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/usr/local/hadoop-3.3.6/bin

# %%
# !hadoop jar /usr/local/hadoop-3.3.6/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar  -files /content/mapper.py,/content/reducer.py -input /content/DataWA.csv -output /content/output/test-mr-1 -mapper 'python3 mapper.py'  -reducer 'python3 reducer.py'
# Out:
# 2024-04-08 03:16:36,645 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2024-04-08 03:16:36,896 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2024-04-08 03:16:36,896 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2024-04-08 03:16:36,927 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-04-08 03:16:37,339 INFO mapred.FileInputFormat: Total input files to process : 1
# 2024-04-08 03:16:37,371 INFO mapreduce.JobSubmitter: number of splits:1
# 2024-04-08 03:16:37,854 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1127465373_0001
# 2024-04-08 03:16:37,855 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-04-08 03:16:38,372 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper.py as file:/tmp/hadoop-root/mapred/local/job_local1127465373_0001_5def2b52-d973-444b-a0f5-90e15fdb6df9/mapper.py
# ...
